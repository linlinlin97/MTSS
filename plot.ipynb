# %%
from _util import *
import _analyzer as analyzer
reload(analyzer)
from matplotlib.transforms import BlendedGenericTransform
import matplotlib.gridspec as gridspec

# import shutil
# shutil.rmtree("res/0316") /
# shutil.rmtree("fig/0327") 
# !tar -czf fig.tar.gz fig/0429/_N50_T100_K5_p10_sigma2

# 1std = .8413 -> 68
# 0.5 std = .6915 -> 38
# 0.25 std = .5987 -> 19.74

# a = load(path)
# n_reps = sum(a['record']['data_plot_BR_original']['time'] == a['record']['data_plot_BR_original']['time'].max()) / 4
# print('n_reps = {}'.format(int(n_reps)))

# %% [markdown]
# ## Cascading

# %%
# # generate all possible combo to compare and select
# for L in [250, 1000]:
#     for p in [3, 5]:
#         for date in [1120, 1124]:
#             try:
#                 reload(analyzer)
#                 fig, axs = plt.subplots(1, 4)
#                 plt.rcParams["figure.figsize"] = [8, 2]
#                 plt.tight_layout()
#                 # fig.suptitle(title, size = 30) 
#                 fig.subplots_adjust(top=0.85)

#                 main_path = 'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
#                 #'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
#                 varing_params = [0.02, 0.05, 0.1, 0.2]
#                 for i in range(4):
#                     path = main_path.format(str(date), str(L), str(p),varing_params[i])
#                     #phi_beta
#                     if i == 0:
#                         ylabel = 'regret'
#                     else:
#                         ylabel = None
#                     handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
#                                   , plot_mean = 0, title = r'$\phi = {}$'.format(varing_params[i]) 
#                                   , skip_methods = None
#                                   , skip = 0, ylabel = ylabel
#                                   , ci = 38 #None
#                                   , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
#                                   , y_min = None, y_max = None)

#                 fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#                 #             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
#                           , bbox_to_anchor = [0.5, -0.55]
#                         , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
#                                )
#                 # fig.suptitle('Horizontally stacked subplots')
#                 ###########
#                 fig.savefig("Fig_final/Cascading_L_{}_p_{}".format(L, p) + ".png"
#                                    , bbox_inches= "tight", dpi = 200)
#             except:
#                 pass

# %%
reload(analyzer)
fig, axs = plt.subplots(1, 3)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)
L = 1000
p = 5
main_path = 'final_res/Cascading/_L1000_T10000_K3_p5/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
varing_params = [0.05, 0.1, 0.2]
for i in range(3):
    path = main_path.format(varing_params[i])
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = r'$\phi = {}$'.format(varing_params[i]) 
                  , skip_methods = None, freq = 200
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci = 38 #None. approximately 68% of data is within +/- 1 standard deviation from the mean; 'sd' = std instead of std of the mean
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                  , y_min = None, y_max = None)

# labels[labels.index("Meta TS (Ours)")] = "MTSS"
# fig.legend(handles, labels, loc='lower center', ncol = len(labels), fontsize = 12
# #             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
#           , bbox_to_anchor = [0.5, -0.62]
#         , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
#                )
fig.suptitle('Cascading bandits', y = 1.15, size = 20)
fig.show()
###########
fig.savefig("Fig_final/Final_Cascading_L_{}_p_{}".format(L, p) + ".pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')

# %%
# palette_idx = {'OSFA' : 14, 'MTB' : 1, "MTB-approx" : 2,'individual-TS' : 11, 'oracle-TS' : 17, 'linear-TS' : 4, 'meta-TS' : 0}
# ax.axis('off')
# ax.set_title(title_pre, pad = 25, size = 16, fontweight= 500)
# labels[labels.index("MTB")] = "MTTS (ours)"
# labels[labels.index("MTB-approx")] = "MTTS-approx"
# fig = plt.figure(figsize=(14, 1.8))
# outer = gridspec.GridSpec(1, 3, wspace=0.14)

# %% [markdown]
# ## Semi-bandits
# 1. Last.fm: L, K, T = 6K, 10, 1000
# 1. another: L, K, T = 30K, 100, 10000

# %%
#             for sigma_1 in [0.5, 0.75, 1, 1.25, 1.5]: 
# for L in [1000, 3000]:
#     for K in [10, 20]:
#         for p in [5, 10]:
#             for sigma_1 in [0.25, 0.5, 1, 1.5]:

# %%
# problem = 'SemiBandit'
# varing_params = [0.5, 0.75, 1, 1.25, 1.5]
# T = 1000
# date = 1123 # 1206
# l = len(varing_params)
# for L in [3000, 1000]:
#     for K in [5, 10]:
#         for p in [5, 10]:
# # for L in [250, 1000]:
# #     for p in [3, 5]:
#             try:
#                 reload(analyzer)
#                 fig, axs = plt.subplots(1, l)
#                 plt.rcParams["figure.figsize"] = [8, 2]
#                 plt.tight_layout()
#                 # fig.suptitle(title, size = 30) 
#                 fig.subplots_adjust(top=0.85)

#                 main_path = 'res/{}/{}/_L{}_T{}_K{}_p{}/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_sigma_1{}_Bandit_typeSemiBandit-50reps'
#                 #'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
#                 for i in range(l):
#                     path = main_path.format(str(date), problem, str(L), str(T), str(K), str(p),varing_params[i])
#                     #phi_beta
#                     if i == 0:
#                         ylabel = 'regret'
#                     else:
#                         ylabel = None
#                     handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
#                                   , plot_mean = 0, title = r'$\phi = {}$'.format(varing_params[i]) 
#                                   , skip_methods = None, freq = 20
#                                   , skip = 0, ylabel = ylabel
#                                   , ci = 38
#                                   , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
#                                   , y_min = None, y_max = None)

#                 fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#                 #             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
#                           , bbox_to_anchor = [0.5, -0.55]
#                         , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
#                                )
#                 # fig.suptitle('Horizontally stacked subplots')
#                 ###########
#                 fig.savefig("Fig_final/{}_L_{}_K_{}_p_{}".format(problem, L, K, p) + ".png"
#                                    , bbox_inches= "tight", dpi = 200)
#             except:
#                 pass

# %%
ps = [
'final_res/_L3000_T1000_K5_p10/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_Bandit_typeSemiBandit-1.22'
, 'final_res/_L3000_T1000_K5_p10/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_sigma_11_Bandit_typeSemiBandit-1'
, 'final_res/_L3000_T1000_K5_p10/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_Bandit_typeSemiBandit-0.71'
]

# %%
problem = 'SemiBandit'
varing_params = [0.75, 1, 1.25]
varing_params_to_print = [0.5, 1, 1.5]
T = 1000
L = 1000
K = 5
p = 10
date = '0102'
reload(analyzer)
fig, axs = plt.subplots(1, 3)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

main_path = 'final_res/{}/_L{}_T{}_K{}_p{}/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_sigma_1{}_Bandit_typeSemiBandit-50reps'
#'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
for i in range(3):
    path = main_path.format(problem, str(L), str(T), str(K), str(p),varing_params[i])
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    handles, labels = analyzer.load_and_plot_ax(ps[i], ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = r'$\sigma_1^2 = {}$'.format(varing_params_to_print[i]) 
                  , skip_methods = None, freq = 20
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci = 38
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                  , y_min = None, y_max = None)
# labels[labels.index("Meta TS (Ours)")] = "MTSS"

# fig.legend(handles, labels, loc='lower center', ncol = len(labels)
# #             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
#         , fontsize = 12
#         , bbox_to_anchor = [0.5, -0.62]
#         , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
#                )
fig.suptitle('Combinatorial semi-bandits', y = 1.15, size = 20)
# fig.suptitle('Horizontally stacked subplots')
###########
fig.savefig("Fig_final/Final_{}_L_{}_K_{}_p_{}".format(problem, L, K, p) + ".pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')

# %%
problem = 'SemiBandit'
varing_params = [0.75, 1, 1.25]
varing_params_to_print = [0.5, 1, 1.5]
T = 1000
date = 1206
L = 3000
K = 10
p = 5
reload(analyzer)
fig, axs = plt.subplots(1, 3)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

main_path = 'final_res/{}/_L{}_T{}_K{}_p{}/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_sigma_1{}_Bandit_typeSemiBandit-50reps'
#'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
for i in range(3):
    path = main_path.format(problem, str(L), str(T), str(K), str(p),varing_params[i])
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = r'$\sigma_1^2 = {}$'.format(varing_params_to_print[i]) 
                  , skip_methods = None, freq = 20
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci = 38
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                  , y_min = None, y_max = None)
# labels[labels.index("Meta TS (Ours)")] = "MTSS"

# fig.legend(handles, labels, loc='lower center', ncol = len(labels)
# #             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
#         , fontsize = 12
#         , bbox_to_anchor = [0.5, -0.62]
#         , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
#                )
fig.suptitle('Combinatorial semi-bandits', y = 1.15, size = 20)
# fig.suptitle('Horizontally stacked subplots')
###########
fig.savefig("Fig_final/Final_{}_L_{}_K_{}_p_{}".format(problem, L, K, p) + ".pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')

# %% [markdown]
# ## MNL
# * real setup: L, T, K, p = 1000, 200000, 5, 5

# %%
L = 1000
p = 3
K = 10
T = 50000
date = 1217
problem = 'MNL'
varing_params = [0.01, 0.02, 0.05] # 0.005, 
l = len(varing_params)
# res/1121/MNL/_L1000_T20000_K5_p5/used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeMNL_phi_beta{}

reload(analyzer)
fig, axs = plt.subplots(1, l)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

# _L1000_T50000_K5_p5/used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeMNL_phi_beta0.005
main_path = 'res/{}/{}/_L{}_T{}_K{}_p{}/LB_freq1_used_agendsall_alpha_GLB1_n_init300_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_with_intercept1_Bandit_typeMNL_phi_beta{}'
#'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
for i in range(l):
    path = main_path.format(str(date), problem, str(L), str(T), str(K), str(p),varing_params[i])
    #phi_beta
    if i == 0:
        ylabel = 'regret'
    else:
        ylabel = None
    handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = r'$\phi = {}$'.format(varing_params[i]) 
                  , skip_methods = None, freq = 100
                  , skip = 0, ylabel = ylabel
                  , ci = 38 #None
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                  , y_min = None, y_max = None)
labels[labels.index("Meta TS (Ours)")] = "MTSS"
fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
          , bbox_to_anchor = [0.5, -0.55]
        , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
               )
# fig.suptitle('Horizontally stacked subplots')
###########
fig.savefig("Fig_final/Final_{}_L_{}_K_{}_p_{}".format(problem, L, K, p) + ".pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-13a1d5f124dc> in <module>
#      32                   , ci = 38 #None
#      33                   , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
# ---> 34                   , y_min = None, y_max = None)
#      35 labels[labels.index("Meta TS (Ours)")] = "MTSS"
#      36 fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#
# ~/SageMaker/MTTS_Structured_Bandits/_analyzer.py in load_and_plot_ax(path, ax, target, plot_mean, title, skip_methods, freq, skip, ylabel, ylabel_size, title_size, ci, names, y_min, y_max)
#      30                   , ci = None, names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
#      31                   , y_min = None, y_max = None):
# ---> 32     a = load(path)
# ...

# %%
L = 1000
p = 5
K = 5
T = 50000
date = 1122
problem = 'MNL'
varing_params = [0.01, 0.02, 0.05] # 0.005, 
l = len(varing_params)
# res/1121/MNL/_L1000_T20000_K5_p5/used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeMNL_phi_beta{}

reload(analyzer)
fig, axs = plt.subplots(1, l)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

# _L1000_T50000_K5_p5/used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeMNL_phi_beta0.005
main_path = 'final_res/{}/_L{}_T{}_K{}_p{}/used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeMNL_phi_beta{}'
#'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
for i in range(l):
    path = main_path.format(problem, str(L), str(T), str(K), str(p),varing_params[i])
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = r'$\phi = {}$'.format(varing_params[i]) 
                  , skip_methods = None, freq = 100
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci = 38 #None
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                  , y_min = None, y_max = None)
labels[labels.index("Meta TS (Ours)")] = "MTSS"
fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
        , fontsize = 12
        , bbox_to_anchor = [0.5, -0.62]
        , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
               )
fig.suptitle('MNL bandits', y = 1.15, size = 20)
###########
fig.savefig("Fig_final/Final_{}_L_{}_K_{}_p_{}".format(problem, L, K, p) + ".pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')

# %% [markdown]
# ## Robustness - Semi

# %%
for w in [1/4, 2/4,3/4, 4/4]:
    varing_params = [0.75, 1, 1.25] #[0.5, 0.75, 1, 1.25, 1.5]
    varing_params_to_print = [0.5, 1, 1.5]
    l = len(varing_params)
    # res/1121/MNL/_L1000_T20000_K5_p5/used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeMNL_phi_beta{}

    reload(analyzer)
    fig, axs = plt.subplots(1, l)
    plt.rcParams["figure.figsize"] = [8, 2]
    plt.tight_layout()
    # fig.suptitle(title, size = 30) 
    fig.subplots_adjust(top=0.85)


    # misspecifications = [("cos", [3/4, 1/4]), ("cos", [2/4, 2/4]), ("cos", [1/4, 3/4]), ("cos", [0/4, 4/4])]
    # for misspecification in misspecifications:
    #     for sigma_1 in : 

    for i in range(l):
        try:
            date = 1211
            main_path = 'final_res/{}/SemiBandit/_L3000_T1000_K10_p5/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_sigma_1{}_Bandit_typeSemiBandit-{}'
            path = main_path.format(str(date), varing_params[i], str(w))
            #phi_beta
            if i == 0:
                ylabel = 'regret'
            else:
                ylabel = None
            handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
                          , plot_mean = 0, title = r'$\sigma_1^2 = {}$'.format(varing_params_to_print[i]) 
                          , skip_methods = None, freq = 100
                          , skip = 0, ylabel = ylabel
                          , ci = 68 #None
                          , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                          , y_min = None, y_max = None)
        except:
            date = 1212
            main_path = 'final_res/{}/SemiBandit/_L3000_T1000_K10_p5/LB_freq1_used_agendsall_alpha_GLB1_n_init2000_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_sigma_1{}_Bandit_typeSemiBandit-{}'
            path = main_path.format(str(date), varing_params[i], str(w))
            #phi_beta
            if i == 0:
                ylabel = 'regret'
            else:
                ylabel = None
            handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
                          , plot_mean = 0, title = r'$\sigma_1^2 = {}$'.format(varing_params_to_print[i]) 
                          , skip_methods = None, freq = 100
                          , skip = 0, ylabel = ylabel
                          , ci = 68 #None
                          , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                          , y_min = None, y_max = None)

    labels[labels.index("Meta TS (Ours)")] = "MTSS"
    fig.legend(handles, labels, loc='lower center', ncol = len(labels)
    #             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
              , bbox_to_anchor = [0.5, -0.55]
            , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
                   )
    # fig.suptitle('Horizontally stacked subplots')
    ###########
    fig.savefig("Fig_final/Final_robust_w_{}".format(w) + ".pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')

# %% [markdown]
# ## Real Datasets

# %%
# a = load(path_MNL)
# a['record']['data_plot_BR_original'].replace({"MNL_TS_Geom": "Feature-agnostic TS"
#                                               , "MNL_feature_determined_TS_Geom": "Feature-determined TS"
#                                              , 'MNL_MTTS_Geom' : 'Meta TS (Ours)'
#                                              , 'MNL_Linear_TS' : 'MNL_Linear_TS'}, inplace=True)
# dump(a, path_MNL)

# %%
# a['record']['data_plot_BR_original'] = a['record']['data_plot_BR_original'][a['record']['data_plot_BR_original'].method != 'MNL_Linear_TS']
# dump(a, 'final_res/Real_MNL_no_linear')

# %%
l = 3

reload(analyzer)
fig, axs = plt.subplots(1, l)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

path_cascading = 'final_res/Cascading_Real'
path_semi = 'final_res/n_female1433_LB_freq1_used_agendsall_alpha_GLB1_n_init300_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_with_intercept0_sigma_21_sigma_10.04_Bandit_typeSemiBandit-SemiBandit_Real'
# path_MNL = 'final_res/Real_MNL'
path_MNL = 'final_res/Real_MNL_no_linear'
paths = [path_cascading, path_semi, path_MNL]
titles = ['Cascading bandits', 'Combinatorial Semi-bandits', 'MNL bandit']
labels_all = {}
for i in range(l):
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    
    handles, labels = analyzer.load_and_plot_ax(paths[i], ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = titles[i]
                  , skip_methods = None, freq = 100
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci = 38 #None
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Feature-determined TS"] # "Oracle TS", 
                  , y_min = None, y_max = None)
    labels_all[i] = labels
labels = labels_all[0]
labels[labels.index("Meta TS (Ours)")] = "MTSS"
fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
          , bbox_to_anchor = [0.5, -0.55]
        , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
               )
###########
fig.savefig("Fig_final/Real.pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')

# %%
# l = 3

# reload(analyzer)
# fig, axs = plt.subplots(1, l)
# plt.rcParams["figure.figsize"] = [8, 2]
# plt.tight_layout()
# # fig.suptitle(title, size = 30) 
# fig.subplots_adjust(top=0.85)

# path_cascading = 'final_res/Cascading_Real'
# path_semi = 'final_res/n_female1433_LB_freq1_used_agendsall_alpha_GLB1_n_init300_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_with_intercept0_sigma_21_sigma_10.04_Bandit_typeSemiBandit-SemiBandit_Real'
# # path_MNL = 'final_res/Real_MNL'
# path_MNL = 'final_res/Real_MNL_no_linear'
# paths = [path_cascading, path_semi, path_MNL]
# titles = ['Cascading bandits', 'Combinatorial Semi-bandits', 'MNL bandit']
# labels_all = {}
# for i in range(l):
#     #phi_beta
#     if i == 0:
#         ylabel = 'Regret'
#     else:
#         ylabel = None
    
#     handles, labels = analyzer.load_and_plot_ax(paths[i], ax = axs[i], target = 'BR'
#                   , plot_mean = 1, title = titles[i]
#                   , skip_methods = None, freq = 100
#                   , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
#                   , ci = 38 #None
#                   , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Feature-determined TS"] # "Oracle TS", 
#                   , y_min = None, y_max = None)
#     labels_all[i] = labels
# labels = labels_all[0]
# labels[labels.index("Meta TS (Ours)")] = "MTSS"
# fig.legend(handles, labels, loc='lower center', ncol = len(labels)
# #             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
#           , bbox_to_anchor = [0.5, -0.55]
#         , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
#                )
# ###########
# # fig.savefig("Fig_final/Real.png"
# #                    , bbox_inches= "tight", dpi = 200)

# %%
l = 3

reload(analyzer)
fig, axs = plt.subplots(1, l)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

path_cascading = 'final_res/Cascading_Real'
path_semi = 'final_res/n_female1433_LB_freq1_used_agendsall_alpha_GLB1_n_init300_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_with_intercept0_sigma_21_sigma_10.04_Bandit_typeSemiBandit-SemiBandit_Real'
# path_MNL = 'final_res/Real_MNL'
path_MNL = 'final_res/Real_MNL_no_linear'
paths = [path_cascading, path_semi, path_MNL]
titles = ['Cascading bandits', 'Combinatorial Semi-bandits', 'MNL bandit']
labels_all = {}
for i in range(l):
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    
    handles, labels = analyzer.load_and_plot_ax(paths[i], ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = titles[i]
                  , skip_methods = None, freq = 100
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci =  0.2 #None
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Feature-determined TS"] # "Oracle TS", 
                  , y_min = None, y_max = None)
    labels_all[i] = labels
labels = labels_all[0]
labels[labels.index("Meta TS (Ours)")] = "MTSS"
fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
          , bbox_to_anchor = [0.5, -0.55]
        , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
               )
###########
# fig.savefig("Fig_final/Real.png"
#                    , bbox_inches= "tight", dpi = 200)

# %%
l = 3

reload(analyzer)
fig, axs = plt.subplots(1, l)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

path_cascading = 'final_res/Cascading_Real'
path_semi = 'final_res/n_female1433_LB_freq1_used_agendsall_alpha_GLB1_n_init300_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_with_intercept0_sigma_21_sigma_10.04_Bandit_typeSemiBandit-SemiBandit_Real'
# path_MNL = 'final_res/Real_MNL'
path_MNL = 'final_res/Real_MNL_no_linear'
paths = [path_cascading, path_semi, path_MNL]
titles = ['Cascading bandits', 'Combinatorial Semi-bandits', 'MNL bandit']
labels_all = {}
for i in range(l):
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    
    handles, labels = analyzer.load_and_plot_ax(paths[i], ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = titles[i]
                  , skip_methods = None, freq = 100
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci =  0.68 #None
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Feature-determined TS"] # "Oracle TS", 
                  , y_min = None, y_max = None)
    labels_all[i] = labels
labels = labels_all[0]
labels[labels.index("Meta TS (Ours)")] = "MTSS"
fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
          , bbox_to_anchor = [0.5, -0.55]
        , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
               )
###########
# fig.savefig("Fig_final/Real.png"
#                    , bbox_inches= "tight", dpi = 200)

# %%
l = 3

reload(analyzer)
fig, axs = plt.subplots(1, l)
plt.rcParams["figure.figsize"] = [7, 1.6]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
# fig.subplots_adjust(top=0.85)

path_cascading = 'final_res/Cascading_Real'
path_semi = 'final_res/n_female1433_LB_freq1_used_agendsall_alpha_GLB1_n_init300_GLB_freq100_MTS_freq50_Sigma_x_factor1_Sigma_gamma_factor1_with_intercept0_sigma_21_sigma_10.04_Bandit_typeSemiBandit-SemiBandit_Real'
# path_MNL = 'final_res/Real_MNL'
path_MNL = 'final_res/Real_MNL_no_linear'
paths = [path_cascading, path_semi, path_MNL]
titles = ['Cascading bandits', 'Combinatorial Semi-bandits', 'MNL bandit']
labels_all = {}
for i in range(l):
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    
    handles, labels = analyzer.load_and_plot_ax(paths[i], ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = titles[i]
                  , skip_methods = None, freq = 100
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 12
                  , ci =  68 #None
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Feature-determined TS"] 
                                                #["Feature-agnostic TS", "Feature-determined TS", "Meta TS (Ours)"] # "Oracle TS", 
                  , y_min = None, y_max = None)
    labels_all[i] = labels
labels = labels_all[0]
labels[labels.index("Meta TS (Ours)")] = "MTSS"
labels[labels.index("MTSS")] = "aa"
labels[labels.index("Feature-determined TS")] = "MTSS (ours)"
labels[labels.index("Feature-agnostic TS")] = "Feature-determined TS"
labels[labels.index("aa")] = "Feature-agnostic TS"

fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
          , bbox_to_anchor = [0.5, -0.75]
        , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
               )
###########
fig.savefig("Fig_final/Real.pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')

# %% [markdown]
# ## Cold Start

# %%
problem = 'SemiBandit'
varing_params = [0, 50, 100, 200]
T = 1000
date = 1206
L = 3000
K = 10
p = 5
reload(analyzer)
fig, axs = plt.subplots(1, 4)
plt.rcParams["figure.figsize"] = [8, 2]
plt.tight_layout()
# fig.suptitle(title, size = 30) 
fig.subplots_adjust(top=0.85)

main_path = 'final_res/cold_start/LB_freq1_used_agendsall_alpha_GLB1_n_init300_GLB_freq100_MTS_freq50_item_update_freq100_item_update_per100{}_Sigma_x_factor1_Sigma_gamma_factor1_sigma_21_sigma_11_Bandit_typeSemiBandit-SemiBandit_cold_Start_{}'
#'res/{}/Cascading/_L{}_T10000_K3_p{}/fixed_gamma0-2_LB_freq1_used_agendsall_alpha_GLB1_n_init500_GLB_freq500_MTS_freq500_Sigma_x_factor1_Sigma_gamma_factor1_Bandit_typeCascading_phi_beta{}-large_scale'
for i in range(4):
    path = main_path.format(varing_params[i], varing_params[i])
    #phi_beta
    if i == 0:
        ylabel = 'Regret'
    else:
        ylabel = None
    handles, labels = analyzer.load_and_plot_ax(path, ax = axs[i], target = 'BR'
                  , plot_mean = 0, title = r'$\Delta N = {}$'.format(varing_params[i]) 
                  , skip_methods = None, freq = 20
                  , skip = 0, ylabel = ylabel, ylabel_size = 16, title_size = 16
                  , ci = 38
                  , names = ["Meta TS (Ours)", "Feature-agnostic TS", "Oracle TS", "Feature-determined TS"]
                  , y_min = None, y_max = None)
# labels[labels.index("Meta TS (Ours)")] = "MTSS"

fig.legend(handles, labels, loc='lower center', ncol = len(labels)
#             , bbox_to_anchor = [1.2, -0.6] # location # 0.4 for my plot
        , fontsize = 12
        , bbox_to_anchor = [0.5, -0.62]
        , bbox_transform = BlendedGenericTransform(fig.transFigure, axs[1].transAxes)
               )
# fig.suptitle('Semi-bandits with Cold-Start Problem', y = 1.15, size = 20)
# fig.suptitle('Horizontally stacked subplots')
###########
fig.savefig("Fig_final/cold_start.pdf"
                   , bbox_inches= "tight", dpi = 200, format = 'pdf')
